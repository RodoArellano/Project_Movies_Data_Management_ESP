# %%
import numpy as np
import pandas as pd

# %%
df_credits_normalized = pd.read_csv('credits_normalized.csv', sep=',')
df_credits_normalized.head(2)
# Out:
#                                                 cast    id          directors
# 0  ['Tom Hanks', 'Tim Allen', 'Don Rickles', 'Jim...   862  ['John Lasseter']
# 1  ['Robin Williams', 'Jonathan Hyde', 'Kirsten D...  8844   ['Joe Johnston']

# %%
df_movies_normalized = pd.read_csv('movies_normalized.csv', sep=',')
df_movies_normalized.head(2)
# Out:
#   belongs_to_collection      budget                              genres    id  \
# 0  Toy Story Collection  30000000.0   ['Animation', 'Comedy', 'Family']   862
# 1                   NaN  65000000.0  ['Adventure', 'Fantasy', 'Family']  8844
#
#   original_language                                           overview  \
# 0                en  Led by Woody, Andy's toys live happily in his ...
# 1                en  When siblings Judy and Peter discover an encha...
#
#    popularity                               production_companies  \
# 0   21.946943                        ['Pixar Animation Studios']
# 1   17.015539  ['TriStar Pictures', 'Teitler Film', 'Intersco...
#
#            production_countries release_date      revenue  runtime  \
# 0  ['United States of America']   1995-10-30  373554033.0     81.0
# 1  ['United States of America']   1995-12-15  262797249.0    104.0
#
#           spoken_languages    status  \
# 0              ['English']  Released
# ...

# %%
df_combined = pd.merge(df_movies_normalized, df_credits_normalized, on='id', how='inner', right_index=False)

# %%
df_combined.head(3)
# Out:
#        belongs_to_collection      budget                              genres  \
# 0       Toy Story Collection  30000000.0   ['Animation', 'Comedy', 'Family']
# 1                        NaN  65000000.0  ['Adventure', 'Fantasy', 'Family']
# 2  Grumpy Old Men Collection         0.0               ['Romance', 'Comedy']
#
#       id original_language                                           overview  \
# 0    862                en  Led by Woody, Andy's toys live happily in his ...
# 1   8844                en  When siblings Judy and Peter discover an encha...
# 2  15602                en  A family wedding reignites the ancient feud be...
#
#    popularity                               production_companies  \
# 0   21.946943                        ['Pixar Animation Studios']
# 1   17.015539  ['TriStar Pictures', 'Teitler Film', 'Intersco...
# 2   11.712900                 ['Warner Bros.', 'Lancaster Gate']
#
#            production_countries release_date  ...         spoken_languages  \
# ...

# %%
df_combined.columns
# Out:
# Index(['belongs_to_collection', 'budget', 'genres', 'id', 'original_language',
#        'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'return', 'release_year', 'cast', 'directors'],
#       dtype='object')

# %%
df_combined.shape
# Out:
# (45451, 22)

# %%
df_combined.isna().sum()
# Me llama la atención que belongs_to_collection tenga tantos nan
# Out:
# belongs_to_collection    40954
# budget                       0
# genres                       0
# id                           0
# original_language           11
# overview                   941
# popularity                   0
# production_companies         0
# production_countries         0
# release_date                 0
# revenue                      0
# runtime                    246
# spoken_languages             0
# status                      80
# tagline                  25026
# title                        0
# vote_average                 0
# vote_count                   0
# return                       0
# release_year                 0
# cast                         0
# directors                    0
# dtype: int64

# %%
#Vuelvo a leer el archivo original para comparar los nan en 'belongs_to_collection'
df_movies = pd.read_csv('movies_dataset.csv', sep=',')
df_movies.head(1)
# Out:
# C:\Users\rodal\AppData\Local\Temp\ipykernel_31536\816858083.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_movies = pd.read_csv('movies_dataset.csv', sep=',')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
#
#   release_date      revenue runtime                          spoken_languages  \
# 0   1995-10-30  373554033.0    81.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
# ...

# %%
df_movies.isna().sum()
# En el archivo original tenía mas, entonces no me voy a preocupar
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %% [markdown]
# Se crea el archivo .csv

# %%
df_combined.to_csv('C:/Users/rodal/Documents/Henry_DS_FT_11/Course_HW/Proyecto_Movies_1/ETL_Project_1/Complete_movies_and_credits_db.csv', index=False)

# %% [markdown]
# Se revisa que se hay creado correctamente

# %%
df_complete = pd.read_csv('complete_movies_and_credits_db.csv', sep=',')
df_complete.head(2)
# Out:
#   belongs_to_collection      budget                              genres    id  \
# 0  Toy Story Collection  30000000.0   ['Animation', 'Comedy', 'Family']   862
# 1                   NaN  65000000.0  ['Adventure', 'Fantasy', 'Family']  8844
#
#   original_language                                           overview  \
# 0                en  Led by Woody, Andy's toys live happily in his ...
# 1                en  When siblings Judy and Peter discover an encha...
#
#    popularity                               production_companies  \
# 0   21.946943                        ['Pixar Animation Studios']
# 1   17.015539  ['TriStar Pictures', 'Teitler Film', 'Intersco...
#
#            production_countries release_date  ...         spoken_languages  \
# 0  ['United States of America']   1995-10-30  ...              ['English']
# 1  ['United States of America']   1995-12-15  ...  ['English', 'Français']
#
#      status                                    tagline      title  \
# ...

# %%
df_complete[['directors']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45451 entries, 0 to 45450
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   directors  45451 non-null  object
# dtypes: object(1)
# memory usage: 355.2+ KB

# %%
df_complete.shape
# Out:
# (45451, 22)

# %% [markdown]
# ÚLTIMOS CAMBIOS

# %% [markdown]
# Para las funciones #1 y #2 se creará la columna 'release_month' y  'release_day'

# %%
df_complete['release_date'] = pd.to_datetime(df_complete['release_date'])

# %%
import locale

# Set Spanish locale
locale.setlocale(locale.LC_TIME, 'es_ES')

# Assuming 'release_date' is a datetime column in your DataFrame
df_complete['release_month'] = df_complete['release_date'].dt.strftime('%B')
df_complete['release_day'] = df_complete['release_date'].dt.strftime('%A')

# Reset the locale to the default (optional)
locale.setlocale(locale.LC_TIME, '')
# Out:
# 'Spanish_Mexico.1252'

# %%
df_complete.head(1)
# Out:
#   belongs_to_collection      budget                             genres   id  \
# 0  Toy Story Collection  30000000.0  ['Animation', 'Comedy', 'Family']  862
#
#   original_language                                           overview  \
# 0                en  Led by Woody, Andy's toys live happily in his ...
#
#    popularity         production_companies          production_countries  \
# 0   21.946943  ['Pixar Animation Studios']  ['United States of America']
#
#   release_date  ...  tagline      title vote_average vote_count     return  \
# 0   1995-10-30  ...      NaN  Toy Story          7.7     5415.0  12.451801
#
#   release_year                                               cast  \
# 0         1995  ['Tom Hanks', 'Tim Allen', 'Don Rickles', 'Jim...
#
#            directors  release_month  release_day
# 0  ['John Lasseter']        octubre        lunes
#
# [1 rows x 24 columns]

# %%
# Convert the datetime values back to string format with the desired format
df_complete['release_date'] = df_complete['release_date'].dt.strftime('%Y-%m-%d')

# %% [markdown]
# Para la función #4 se debe convertir la columna 'vote_count' en int

# %%
df_complete['vote_count'] = df_complete['vote_count'].astype(int)

# %% [markdown]
# Revisamos el tipo de dato return para la función #5

# %%
print(type(df_complete['return'][0]))
# Out:
# <class 'numpy.float64'>

# %%
# Vemos que en la fila 5 tenemos un valor infinito
df_complete.head(5)
# Out:
#             belongs_to_collection      budget  \
# 0            Toy Story Collection  30000000.0
# 1                             NaN  65000000.0
# 2       Grumpy Old Men Collection         0.0
# 3                             NaN  16000000.0
# 4  Father of the Bride Collection         0.0
#
#                                genres     id original_language  \
# 0   ['Animation', 'Comedy', 'Family']    862                en
# 1  ['Adventure', 'Fantasy', 'Family']   8844                en
# 2               ['Romance', 'Comedy']  15602                en
# 3      ['Comedy', 'Drama', 'Romance']  31357                en
# 4                          ['Comedy']  11862                en
#
#                                             overview  popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1  When siblings Judy and Peter discover an encha...   17.015539
# 2  A family wedding reignites the ancient feud be...   11.712900
# ...

# %%
#identificamos los infinitos
inf_count = np.isinf(df_complete['return']).sum()
print(f'numero de valores infinitos {inf_count}')

inf_ = np.isinf(df_complete['return'])
print(inf_)
# Out:
# numero de valores infinitos 2034
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 45446    False
# 45447    False
# 45448    False
# 45449    False
# 45450    False
# Name: return, Length: 45451, dtype: bool

# %% [markdown]
# Para aligerar al archivo se elimina la columna no utilizada: 'tagline'

# %%
df_complete.drop(['tagline'], axis=1,inplace=True)

# %% [markdown]
# Se sube el update del archivo definitivo

# %%
df_complete.to_csv('C:/Users/rodal/Documents/Henry_DS_FT_11/Course_HW/Proyecto_Movies_1/ETL_Project_1/Complete_movies_and_credits_db.csv', index=False)

# %% [markdown]
# Se vuelve a revisar que se haya cargado correctamente:

# %%
df_complete = pd.read_csv('complete_movies_and_credits_db.csv', sep=',')
df_complete.head(2)
# Out:
#   belongs_to_collection      budget                              genres    id  \
# 0  Toy Story Collection  30000000.0   ['Animation', 'Comedy', 'Family']   862
# 1                   NaN  65000000.0  ['Adventure', 'Fantasy', 'Family']  8844
#
#   original_language                                           overview  \
# 0                en  Led by Woody, Andy's toys live happily in his ...
# 1                en  When siblings Judy and Peter discover an encha...
#
#    popularity                               production_companies  \
# 0   21.946943                        ['Pixar Animation Studios']
# 1   17.015539  ['TriStar Pictures', 'Teitler Film', 'Intersco...
#
#            production_countries release_date  ...    status      title  \
# 0  ['United States of America']   1995-10-30  ...  Released  Toy Story
# 1  ['United States of America']   1995-12-15  ...  Released    Jumanji
#
#   vote_average vote_count     return  release_year  \
# ...

# %%
df_complete.shape
# Out:
# (45451, 23)

# %%
df_complete.columns
# Out:
# Index(['belongs_to_collection', 'budget', 'genres', 'id', 'original_language',
#        'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'title', 'vote_average', 'vote_count',
#        'return', 'release_year', 'cast', 'directors', 'release_month',
#        'release_day'],
#       dtype='object')
